# %% [markdown]
# # Using Pandas

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
#It will show pandas version as well as its dependencies 
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.6.1.final.0
# python-bits: 64
# OS: Windows
# OS-release: 10
# machine: AMD64
# processor: Intel64 Family 6 Model 61 Stepping 4, GenuineIntel
# byteorder: little
# LC_ALL: None
# LANG: None
# LOCALE: None.None
#
# pandas: 0.23.0
# pytest: 3.0.7
# pip: 10.0.1
# setuptools: 38.4.0
# Cython: 0.25.2
# numpy: 1.14.0
# scipy: 1.0.0
# pyarrow: None
# xarray: None
# IPython: 5.3.0
# sphinx: 1.5.6
# patsy: 0.4.1
# dateutil: 2.6.1
# pytz: 2017.2
# blosc: None
# bottleneck: 1.2.1
# tables: 3.2.2
# numexpr: 2.6.2
# feather: None
# matplotlib: 2.0.2
# openpyxl: 2.4.7
# xlrd: 1.0.0
# xlwt: 1.2.0
# xlsxwriter: 0.9.6
# lxml: 3.7.3
# bs4: 4.6.0
# html5lib: 0.9999999
# sqlalchemy: 1.1.9
# pymysql: None
# psycopg2: None
# jinja2: 2.9.6
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: None

# %%
#Pandas documentation to see doc string of the method ,press shift+tab 
pd.show_versions?

# %% [markdown]
# # Series and DataFrames

# %%
olymbic_df = pd.read_csv('./data/olympics.csv',skiprows=4)
olymbic_df.head() # to see top 5 records
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olymbic_df.tail() # To see last 5 records
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
olymbic_df.NOC # List NOC Column
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
olymbic_df['NOC'] # Another way of listing 'NOC' column
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %% [markdown]
# ## Accessing data frame Series

# %%
olymbic_df[['Edition','Sport','Discipline']]
# Out:
#        Edition      Sport       Discipline
# 0         1896   Aquatics         Swimming
# 1         1896   Aquatics         Swimming
# 2         1896   Aquatics         Swimming
# 3         1896   Aquatics         Swimming
# 4         1896   Aquatics         Swimming
# 5         1896   Aquatics         Swimming
# 6         1896   Aquatics         Swimming
# 7         1896   Aquatics         Swimming
# 8         1896   Aquatics         Swimming
# 9         1896   Aquatics         Swimming
# 10        1896   Aquatics         Swimming
# 11        1896  Athletics        Athletics
# 12        1896  Athletics        Athletics
# 13        1896  Athletics        Athletics
# 14        1896  Athletics        Athletics
# 15        1896  Athletics        Athletics
# 16        1896  Athletics        Athletics
# 17        1896  Athletics        Athletics
# 18        1896  Athletics        Athletics
# 19        1896  Athletics        Athletics
# 20        1896  Athletics        Athletics
# ...

# %% [markdown]
# ## Check the pandas different type of objects

# %%
type(olymbic_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(olymbic_df.NOC)
# Out:
# pandas.core.series.Series

# %%
type(olymbic_df[['City','Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame
